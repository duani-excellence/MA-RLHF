# %%
from datasets import load_dataset

dataset_path = './output/alpaca_gpt4_data_zh.json'

dataset = load_dataset('json', data_files=dataset_path)

print(dataset)
# Out:
# /Users/denghang/Miniconda3/envs/llm/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 48818
#     })
# })

# %%
# !huggingface-cli whoami
# Out:
# xiaodongguaAIGC

# %%
dataset.push_to_hub("xiaodongguaAIGC/alpaca_gpt4_data_zh")

# %%
from datasets import load_from_disk
my_data = './output/alpaca_en_zh_ruozhiba'
mix_dataset = load_from_disk(my_data)
# Out:
# /Users/denghang/Miniconda3/envs/llm/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
mix_dataset.push_to_hub("xiaodongguaAIGC/alpaca_en_zh_ruozhiba")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/112 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CommitInfo(
# │   commit_url='https://huggingface.co/datasets/xiaodongguaAIGC/alpaca_en_zh_ruozhiba/commit/b3a4e77c8c37c0d58a88dabcd2193fdd3c7a90a8',
# │   commit_message='Upload dataset',
# │   commit_description='',
# │   oid='b3a4e77c8c37c0d58a88dabcd2193fdd3c7a90a8',
# │   pr_url=None,
# │   pr_revision=None,
# │   pr_num=None
# )

# %% [markdown]
# # CVALUES

# %%
# download from 'https://www.modelscope.cn/datasets/iic/CValues-Comparison/files'

dataset_path = './test.jsonl'
test_dataset = load_dataset('json', data_files=dataset_path)
print(test_dataset)

dataset_path = './train.jsonl'
train_dataset = load_dataset('json', data_files=dataset_path)
print(train_dataset)

train_dataset['test'] = test_dataset['train']
dataset = train_dataset
print(train_dataset)

# %%
train_dataset.push_to_hub("xiaodongguaAIGC/CValues")

# %%
def process_cvalues(examples):
    examples['chosen'] = examples['pos_resp']
    examples['rejected'] = examples['neg_resp']
    return examples
dataset = dataset.map(process_cvalues,
                            num_proc=8,
                            remove_columns = ["pos_resp",'neg_resp','pos_type','neg_type']
                           )
print(dataset)

# %%
dataset.push_to_hub("xiaodongguaAIGC/CValues_DPO")
