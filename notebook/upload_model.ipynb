# %%
import huggingface_hub

huggingface_hub.logout()
# Out:
# Successfully logged out.

# %%
# !export HF_ENDPOINT=https://hf-mirror.com

# %%
# 登陆Huggingface， 这里的Acesse Token需要Write权限
from huggingface_hub import notebook_login
from huggingface_hub import create_repo
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# model_name ='./../output/dpo/sft_lora'
# hf_repo_name = 'llama-2-7b-sft-lora'

# model_name ='./../output/dpo/sft_full'
# hf_repo_name = 'llama-2-7b-sft-full'

# model_name ='./../output/dpo/dpo_lora'
# hf_repo_name = 'llama-2-7b-dpo-lora'

model_name ='./../output/dpo/dpo_full'
hf_repo_name = 'llama-2-7b-dpo-full'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, HfArgumentParser

device = 'cpu'
model = AutoModelForCausalLM.from_pretrained(
    model_name, torch_dtype=torch.bfloat16,
    trust_remote_code=True,
).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True,)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# 创建仓库
create_repo(hf_repo_name)

# 上传Model和Tokenizer
model.push_to_hub(hf_repo_name)
tokenizer.push_to_hub(hf_repo_name)
# Out:
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/xiaodongguaAIGC/llama-2-7b-dpo-full/commit/98b9f7fc4704a3d7c595c360a829b8536008fbaa', commit_message='Upload tokenizer', commit_description='', oid='98b9f7fc4704a3d7c595c360a829b8536008fbaa', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Out:
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/xiaodongguaAIGC/llama_7b_sft_full/commit/c894aa2d1030fe570d9719b6da6572602fa90775', commit_message='Upload tokenizer', commit_description='', oid='c894aa2d1030fe570d9719b6da6572602fa90775', pr_url=None, pr_revision=None, pr_num=None)
